# %%
import pandas as pd
from data_import import *
from next_days_precipitation_predictor import NextDaysPrecipitationPredictor
from models import *
pd.set_option('display.max_columns', 500)

# %%
p = NextDaysPrecipitationPredictor(psatjira_models[1], "PSATJIRA")

# %%
result, df = p.predict_next_x_days(15, True)
# Out:
# c:\Users\Samsung\Desktop\ITA\3ºSemestre_Comp_ITA\GED-20\Projeto\desafio-casa-dos-ventos-ged-20\src\next_days_precipitation_predictor.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_new = pd.concat([df, df_x_days], axis=0)

# %%
df.tail(30)
# Out:
#             mean_precipitation      lag_1      lag_2      lag_3      lag_4  \
# 2024-03-20            1.276238   0.325767   3.921167  12.659788   2.167305
# 2024-03-21            3.537854   1.276238   0.325767   3.921167  12.659788
# 2024-03-22           12.304186   3.537854   1.276238   0.325767   3.921167
# 2024-03-23           24.543809  12.304186   3.537854   1.276238   0.325767
# 2024-03-24            0.084965  24.543809  12.304186   3.537854   1.276238
# 2024-03-25            0.908314   0.084965  24.543809  12.304186   3.537854
# 2024-03-26            2.765212   0.908314   0.084965  24.543809  12.304186
# 2024-03-27            1.709139   2.765212   0.908314   0.084965  24.543809
# 2024-03-28            1.717748   1.709139   2.765212   0.908314   0.084965
# 2024-03-29            1.559375   1.717748   1.709139   2.765212   0.908314
# 2024-03-30            2.921875   1.559375   1.717748   1.709139   2.765212
# ...
